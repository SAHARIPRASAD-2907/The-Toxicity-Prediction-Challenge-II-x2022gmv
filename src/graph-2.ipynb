# %%
import pandas as pd
import numpy as np

# %%
graph_data = pd.read_csv("./scores.csv")

# %%
graph_data
# Out:
#     Index  F1 score-local  F1 score-global
# 0       1        0.000000          0.49693
# 1       2        0.000000          0.49853
# 2       3        0.000000          0.49853
# 3       4        0.000000          0.67663
# 4       5        0.000000          0.66746
# ..    ...             ...              ...
# 94     95        0.648314          0.80959
# 95     96        0.948314          0.81125
# 96     97        0.950314          0.80986
# 97     98        0.950314          0.81084
# 98     99        0.950314          0.81137
#
# [99 rows x 3 columns]

# %%
y = graph_data["Index"]
x1 = graph_data["F1 score-local"]*100
x2 = graph_data["F1 score-global"]*100

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
plt.plot(y, x2, label = "Kaagle score",marker="x")
plt.plot(y, x1, label = "Local score",marker="o")
plt.axvline(55,color="g",label="Submission after presentation 1")
plt.axvline(94,color="y",label="Best submission")
plt.legend()
plt.xlabel("Submission number")
plt.ylabel("F1 score")
plt.title("Presentation 2 (x2022gmv)")
plt.show()
