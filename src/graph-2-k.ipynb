# %%
import pandas as pd
import numpy as np

# %%
graph_data = pd.read_csv("../sample_scores.csv")

# %%
graph_data
# Out:
#     submission_number  my_score  kaagle_score
# 0                   1   0.00000       0.46243
# 1                   2   0.00000       0.61757
# 2                   3   0.00000       0.61719
# 3                   4   0.00000       0.62305
# 4                   5   0.00000       0.62366
# 5                   6   0.00000       0.62715
# 6                   7   0.00000       0.63103
# 7                   8   0.00000       0.63103
# 8                   9   0.00000       0.63661
# 9                  10   0.00000       0.64028
# 10                 11   0.00000       0.64182
# 11                 12   0.00000       0.64182
# 12                 13   0.00000       0.55874
# 13                 14   0.00000       0.64182
# 14                 15   0.00000       0.74215
# 15                 16   0.32726       0.63187
# 16                 17   0.39103       0.66413
# 17                 18   0.30809       0.60473
# 18                 19   0.43014       0.69476
# ...

# %%
y = graph_data["submission_number"]
x1 = graph_data["my_score"]
x2 = graph_data["kaagle_score"]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(y, x2, label = "Internal Cross Validation Mean Score")
plt.plot(y, x1, label = "Leaderboard F1 Score")
plt.legend()
plt.xlabel("Submissions")
plt.ylabel("score")
plt.title("Toxic data prediction")
plt.show()
