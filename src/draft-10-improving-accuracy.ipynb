# %% [markdown]
# # Making imports

# %%
import pandas as pd
import numpy as np 
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
pd.set_option('display.max_rows', 500) # Set max output 500
pd.set_option('display.max_columns',500)
import matplotlib.pyplot as plt
np.random.seed(50) # Setting random seed for reproducable results

# %%
train_data = pd.read_csv("./smile_description_train.csv")
test_data = pd.read_csv("./smile_description_test.csv")
auc_scores = pd.read_csv("./AUC_VALUES.csv")

# %% [markdown]
# # Defining all global function

# %%
def get_data_info(data):
    print(data.info(verbose=-1))

# %%
def get_missing_values(data):
    print(test_data.isna().sum())

# %%
def drop_columns_and_rows_with_no_null_values(data):
    for col in data:
        missing_values = data[col].isna().sum()
        if(missing_values!=0 and col!='label'):
            data = data.drop(col,axis=1);
    data = data.dropna()
    return data;

# %%
def get_count_of_ones_and_twos(predict):
    print("Number of predicted ones",np.count_nonzero(predict==1))
    print("Number of predicted twos",np.count_nonzero(predict==2))

# %%
def create_submission(predict,filename):
    sub_file = pd.read_csv("./data/sample_submission.csv")
    sub_file["Predicted"] = predict
    sub_file.to_csv(filename,index=False)
    print(filename," Created")

# %% [markdown]
# # Analysing Data

# %%
# Getting training data info
get_data_info(train_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75383 entries, 0 to 75382
# Data columns (total 210 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    MaxEStateIndex            float64
#  1    MinEStateIndex            float64
#  2    MaxAbsEStateIndex         float64
#  3    MinAbsEStateIndex         float64
#  4    qed                       float64
#  5    MolWt                     float64
#  6    HeavyAtomMolWt            float64
#  7    ExactMolWt                float64
#  8    NumValenceElectrons       float64
#  9    NumRadicalElectrons       float64
#  10   MaxPartialCharge          float64
#  11   MinPartialCharge          float64
#  12   MaxAbsPartialCharge       float64
#  13   MinAbsPartialCharge       float64
#  14   FpDensityMorgan1          float64
#  15   FpDensityMorgan2          float64
#  16   FpDensityMorgan3          float64
#  17   BCUT2D_MWHI               float64
#  18   BCUT2D_MWLOW              float64
#  19   BCUT2D_CHGHI              float64
#  20   BCUT2D_CHGLO              float64
#  21   BCUT2D_LOGPHI             float64
#  22   BCUT2D_LOGPLOW            float64
#  23   BCUT2D_MRHI               float64
#  24   BCUT2D_MRLOW              float64
#  25   BalabanJ                  float64
#  26   BertzCT                   float64
#  27   Chi0                      float64
#  28   Chi0n                     float64
#  29   Chi0v                     float64
#  30   Chi1                      float64
#  31   Chi1n                     float64
#  32   Chi1v                     float64
#  33   Chi2n                     float64
#  34   Chi2v                     float64
#  35   Chi3n                     float64
#  36   Chi3v                     float64
#  37   Chi4n                     float64
#  38   Chi4v                     float64
#  39   HallKierAlpha             float64
#  40   Ipc                       float64
#  41   Kappa1                    float64
#  42   Kappa2                    float64
#  43   Kappa3                    float64
#  44   LabuteASA                 float64
#  45   PEOE_VSA1                 float64
#  46   PEOE_VSA10                float64
#  47   PEOE_VSA11                float64
#  48   PEOE_VSA12                float64
#  49   PEOE_VSA13                float64
#  50   PEOE_VSA14                float64
#  51   PEOE_VSA2                 float64
#  52   PEOE_VSA3                 float64
#  53   PEOE_VSA4                 float64
#  54   PEOE_VSA5                 float64
#  55   PEOE_VSA6                 float64
#  56   PEOE_VSA7                 float64
#  57   PEOE_VSA8                 float64
#  58   PEOE_VSA9                 float64
#  59   SMR_VSA1                  float64
#  60   SMR_VSA10                 float64
#  61   SMR_VSA2                  float64
#  62   SMR_VSA3                  float64
#  63   SMR_VSA4                  float64
#  64   SMR_VSA5                  float64
#  65   SMR_VSA6                  float64
#  66   SMR_VSA7                  float64
#  67   SMR_VSA8                  float64
#  68   SMR_VSA9                  float64
#  69   SlogP_VSA1                float64
#  70   SlogP_VSA10               float64
#  71   SlogP_VSA11               float64
#  72   SlogP_VSA12               float64
#  73   SlogP_VSA2                float64
#  74   SlogP_VSA3                float64
#  75   SlogP_VSA4                float64
#  76   SlogP_VSA5                float64
#  77   SlogP_VSA6                float64
#  78   SlogP_VSA7                float64
#  79   SlogP_VSA8                float64
#  80   SlogP_VSA9                float64
#  81   TPSA                      float64
#  82   EState_VSA1               float64
#  83   EState_VSA10              float64
#  84   EState_VSA11              float64
#  85   EState_VSA2               float64
#  86   EState_VSA3               float64
#  87   EState_VSA4               float64
#  88   EState_VSA5               float64
#  89   EState_VSA6               float64
#  90   EState_VSA7               float64
#  91   EState_VSA8               float64
#  92   EState_VSA9               float64
#  93   VSA_EState1               float64
#  94   VSA_EState10              float64
#  95   VSA_EState2               float64
#  96   VSA_EState3               float64
#  97   VSA_EState4               float64
#  98   VSA_EState5               float64
#  99   VSA_EState6               float64
#  100  VSA_EState7               float64
#  101  VSA_EState8               float64
#  102  VSA_EState9               float64
#  103  FractionCSP3              float64
#  104  HeavyAtomCount            float64
#  105  NHOHCount                 float64
#  106  NOCount                   float64
#  107  NumAliphaticCarbocycles   float64
#  108  NumAliphaticHeterocycles  float64
#  109  NumAliphaticRings         float64
#  110  NumAromaticCarbocycles    float64
#  111  NumAromaticHeterocycles   float64
#  112  NumAromaticRings          float64
#  113  NumHAcceptors             float64
#  114  NumHDonors                float64
#  115  NumHeteroatoms            float64
#  116  NumRotatableBonds         float64
#  117  NumSaturatedCarbocycles   float64
#  118  NumSaturatedHeterocycles  float64
#  119  NumSaturatedRings         float64
#  120  RingCount                 float64
#  121  MolLogP                   float64
#  122  MolMR                     float64
#  123  fr_Al_COO                 float64
#  124  fr_Al_OH                  float64
#  125  fr_Al_OH_noTert           float64
#  126  fr_ArN                    float64
#  127  fr_Ar_COO                 float64
#  128  fr_Ar_N                   float64
#  129  fr_Ar_NH                  float64
#  130  fr_Ar_OH                  float64
#  131  fr_COO                    float64
#  132  fr_COO2                   float64
#  133  fr_C_O                    float64
#  134  fr_C_O_noCOO              float64
#  135  fr_C_S                    float64
#  136  fr_HOCCN                  float64
#  137  fr_Imine                  float64
#  138  fr_NH0                    float64
#  139  fr_NH1                    float64
#  140  fr_NH2                    float64
#  141  fr_N_O                    float64
#  142  fr_Ndealkylation1         float64
#  143  fr_Ndealkylation2         float64
#  144  fr_Nhpyrrole              float64
#  145  fr_SH                     float64
#  146  fr_aldehyde               float64
#  147  fr_alkyl_carbamate        float64
#  148  fr_alkyl_halide           float64
#  149  fr_allylic_oxid           float64
#  150  fr_amide                  float64
#  151  fr_amidine                float64
#  152  fr_aniline                float64
#  153  fr_aryl_methyl            float64
#  154  fr_azide                  float64
#  155  fr_azo                    float64
#  156  fr_barbitur               float64
#  157  fr_benzene                float64
#  158  fr_benzodiazepine         float64
#  159  fr_bicyclic               float64
#  160  fr_diazo                  float64
#  161  fr_dihydropyridine        float64
#  162  fr_epoxide                float64
#  163  fr_ester                  float64
#  164  fr_ether                  float64
#  165  fr_furan                  float64
#  166  fr_guanido                float64
#  167  fr_halogen                float64
#  168  fr_hdrzine                float64
#  169  fr_hdrzone                float64
#  170  fr_imidazole              float64
#  171  fr_imide                  float64
#  172  fr_isocyan                float64
#  173  fr_isothiocyan            float64
#  174  fr_ketone                 float64
#  175  fr_ketone_Topliss         float64
#  176  fr_lactam                 float64
#  177  fr_lactone                float64
#  178  fr_methoxy                float64
#  179  fr_morpholine             float64
#  180  fr_nitrile                float64
#  181  fr_nitro                  float64
#  182  fr_nitro_arom             float64
#  183  fr_nitro_arom_nonortho    float64
#  184  fr_nitroso                float64
#  185  fr_oxazole                float64
#  186  fr_oxime                  float64
#  187  fr_para_hydroxylation     float64
#  188  fr_phenol                 float64
#  189  fr_phenol_noOrthoHbond    float64
#  190  fr_phos_acid              float64
#  191  fr_phos_ester             float64
#  192  fr_piperdine              float64
#  193  fr_piperzine              float64
#  194  fr_priamide               float64
#  195  fr_prisulfonamd           float64
#  196  fr_pyridine               float64
#  197  fr_quatN                  float64
#  198  fr_sulfide                float64
#  199  fr_sulfonamd              float64
#  200  fr_sulfone                float64
#  201  fr_term_acetylene         float64
#  202  fr_tetrazole              float64
#  203  fr_thiazole               float64
#  204  fr_thiocyan               float64
#  205  fr_thiophene              float64
#  206  fr_unbrch_alkane          float64
#  207  fr_urea                   float64
#  208  label                     int64
#  209  Assay_id                  int64
# dtypes: float64(208), int64(2)
# memory usage: 120.8 MB
# None

# %%
# Getting testing data info
get_data_info(test_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10994 entries, 0 to 10993
# Data columns (total 209 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    MaxEStateIndex            float64
#  1    MinEStateIndex            float64
#  2    MaxAbsEStateIndex         float64
#  3    MinAbsEStateIndex         float64
#  4    qed                       float64
#  5    MolWt                     float64
#  6    HeavyAtomMolWt            float64
#  7    ExactMolWt                float64
#  8    NumValenceElectrons       float64
#  9    NumRadicalElectrons       float64
#  10   MaxPartialCharge          float64
#  11   MinPartialCharge          float64
#  12   MaxAbsPartialCharge       float64
#  13   MinAbsPartialCharge       float64
#  14   FpDensityMorgan1          float64
#  15   FpDensityMorgan2          float64
#  16   FpDensityMorgan3          float64
#  17   BCUT2D_MWHI               float64
#  18   BCUT2D_MWLOW              float64
#  19   BCUT2D_CHGHI              float64
#  20   BCUT2D_CHGLO              float64
#  21   BCUT2D_LOGPHI             float64
#  22   BCUT2D_LOGPLOW            float64
#  23   BCUT2D_MRHI               float64
#  24   BCUT2D_MRLOW              float64
#  25   BalabanJ                  float64
#  26   BertzCT                   float64
#  27   Chi0                      float64
#  28   Chi0n                     float64
#  29   Chi0v                     float64
#  30   Chi1                      float64
#  31   Chi1n                     float64
#  32   Chi1v                     float64
#  33   Chi2n                     float64
#  34   Chi2v                     float64
#  35   Chi3n                     float64
#  36   Chi3v                     float64
#  37   Chi4n                     float64
#  38   Chi4v                     float64
#  39   HallKierAlpha             float64
#  40   Ipc                       float64
#  41   Kappa1                    float64
#  42   Kappa2                    float64
#  43   Kappa3                    float64
#  44   LabuteASA                 float64
#  45   PEOE_VSA1                 float64
#  46   PEOE_VSA10                float64
#  47   PEOE_VSA11                float64
#  48   PEOE_VSA12                float64
#  49   PEOE_VSA13                float64
#  50   PEOE_VSA14                float64
#  51   PEOE_VSA2                 float64
#  52   PEOE_VSA3                 float64
#  53   PEOE_VSA4                 float64
#  54   PEOE_VSA5                 float64
#  55   PEOE_VSA6                 float64
#  56   PEOE_VSA7                 float64
#  57   PEOE_VSA8                 float64
#  58   PEOE_VSA9                 float64
#  59   SMR_VSA1                  float64
#  60   SMR_VSA10                 float64
#  61   SMR_VSA2                  float64
#  62   SMR_VSA3                  float64
#  63   SMR_VSA4                  float64
#  64   SMR_VSA5                  float64
#  65   SMR_VSA6                  float64
#  66   SMR_VSA7                  float64
#  67   SMR_VSA8                  float64
#  68   SMR_VSA9                  float64
#  69   SlogP_VSA1                float64
#  70   SlogP_VSA10               float64
#  71   SlogP_VSA11               float64
#  72   SlogP_VSA12               float64
#  73   SlogP_VSA2                float64
#  74   SlogP_VSA3                float64
#  75   SlogP_VSA4                float64
#  76   SlogP_VSA5                float64
#  77   SlogP_VSA6                float64
#  78   SlogP_VSA7                float64
#  79   SlogP_VSA8                float64
#  80   SlogP_VSA9                float64
#  81   TPSA                      float64
#  82   EState_VSA1               float64
#  83   EState_VSA10              float64
#  84   EState_VSA11              float64
#  85   EState_VSA2               float64
#  86   EState_VSA3               float64
#  87   EState_VSA4               float64
#  88   EState_VSA5               float64
#  89   EState_VSA6               float64
#  90   EState_VSA7               float64
#  91   EState_VSA8               float64
#  92   EState_VSA9               float64
#  93   VSA_EState1               float64
#  94   VSA_EState10              float64
#  95   VSA_EState2               float64
#  96   VSA_EState3               float64
#  97   VSA_EState4               float64
#  98   VSA_EState5               float64
#  99   VSA_EState6               float64
#  100  VSA_EState7               float64
#  101  VSA_EState8               float64
#  102  VSA_EState9               float64
#  103  FractionCSP3              float64
#  104  HeavyAtomCount            float64
#  105  NHOHCount                 float64
#  106  NOCount                   float64
#  107  NumAliphaticCarbocycles   float64
#  108  NumAliphaticHeterocycles  float64
#  109  NumAliphaticRings         float64
#  110  NumAromaticCarbocycles    float64
#  111  NumAromaticHeterocycles   float64
#  112  NumAromaticRings          float64
#  113  NumHAcceptors             float64
#  114  NumHDonors                float64
#  115  NumHeteroatoms            float64
#  116  NumRotatableBonds         float64
#  117  NumSaturatedCarbocycles   float64
#  118  NumSaturatedHeterocycles  float64
#  119  NumSaturatedRings         float64
#  120  RingCount                 float64
#  121  MolLogP                   float64
#  122  MolMR                     float64
#  123  fr_Al_COO                 float64
#  124  fr_Al_OH                  float64
#  125  fr_Al_OH_noTert           float64
#  126  fr_ArN                    float64
#  127  fr_Ar_COO                 float64
#  128  fr_Ar_N                   float64
#  129  fr_Ar_NH                  float64
#  130  fr_Ar_OH                  float64
#  131  fr_COO                    float64
#  132  fr_COO2                   float64
#  133  fr_C_O                    float64
#  134  fr_C_O_noCOO              float64
#  135  fr_C_S                    float64
#  136  fr_HOCCN                  float64
#  137  fr_Imine                  float64
#  138  fr_NH0                    float64
#  139  fr_NH1                    float64
#  140  fr_NH2                    float64
#  141  fr_N_O                    float64
#  142  fr_Ndealkylation1         float64
#  143  fr_Ndealkylation2         float64
#  144  fr_Nhpyrrole              float64
#  145  fr_SH                     float64
#  146  fr_aldehyde               float64
#  147  fr_alkyl_carbamate        float64
#  148  fr_alkyl_halide           float64
#  149  fr_allylic_oxid           float64
#  150  fr_amide                  float64
#  151  fr_amidine                float64
#  152  fr_aniline                float64
#  153  fr_aryl_methyl            float64
#  154  fr_azide                  float64
#  155  fr_azo                    float64
#  156  fr_barbitur               float64
#  157  fr_benzene                float64
#  158  fr_benzodiazepine         float64
#  159  fr_bicyclic               float64
#  160  fr_diazo                  float64
#  161  fr_dihydropyridine        float64
#  162  fr_epoxide                float64
#  163  fr_ester                  float64
#  164  fr_ether                  float64
#  165  fr_furan                  float64
#  166  fr_guanido                float64
#  167  fr_halogen                float64
#  168  fr_hdrzine                float64
#  169  fr_hdrzone                float64
#  170  fr_imidazole              float64
#  171  fr_imide                  float64
#  172  fr_isocyan                float64
#  173  fr_isothiocyan            float64
#  174  fr_ketone                 float64
#  175  fr_ketone_Topliss         float64
#  176  fr_lactam                 float64
#  177  fr_lactone                float64
#  178  fr_methoxy                float64
#  179  fr_morpholine             float64
#  180  fr_nitrile                float64
#  181  fr_nitro                  float64
#  182  fr_nitro_arom             float64
#  183  fr_nitro_arom_nonortho    float64
#  184  fr_nitroso                float64
#  185  fr_oxazole                float64
#  186  fr_oxime                  float64
#  187  fr_para_hydroxylation     float64
#  188  fr_phenol                 float64
#  189  fr_phenol_noOrthoHbond    float64
#  190  fr_phos_acid              float64
#  191  fr_phos_ester             float64
#  192  fr_piperdine              float64
#  193  fr_piperzine              float64
#  194  fr_priamide               float64
#  195  fr_prisulfonamd           float64
#  196  fr_pyridine               float64
#  197  fr_quatN                  float64
#  198  fr_sulfide                float64
#  199  fr_sulfonamd              float64
#  200  fr_sulfone                float64
#  201  fr_term_acetylene         float64
#  202  fr_tetrazole              float64
#  203  fr_thiazole               float64
#  204  fr_thiocyan               float64
#  205  fr_thiophene              float64
#  206  fr_unbrch_alkane          float64
#  207  fr_urea                   float64
#  208  Assay_id                  int64
# dtypes: float64(208), int64(1)
# memory usage: 17.5 MB
# None

# %%
# Getting missing values of traning data
get_missing_values(train_data)
# Out:
# MaxEStateIndex                0
# MinEStateIndex                0
# MaxAbsEStateIndex             0
# MinAbsEStateIndex             0
# qed                           0
# MolWt                         0
# HeavyAtomMolWt                0
# ExactMolWt                    0
# NumValenceElectrons           0
# NumRadicalElectrons           0
# MaxPartialCharge             48
# MinPartialCharge             48
# MaxAbsPartialCharge          48
# MinAbsPartialCharge          48
# FpDensityMorgan1              0
# FpDensityMorgan2              0
# FpDensityMorgan3              0
# BCUT2D_MWHI                 493
# BCUT2D_MWLOW                493
# BCUT2D_CHGHI                493
# BCUT2D_CHGLO                493
# BCUT2D_LOGPHI               493
# BCUT2D_LOGPLOW              493
# BCUT2D_MRHI                 493
# BCUT2D_MRLOW                493
# BalabanJ                      0
# BertzCT                       0
# Chi0                          0
# Chi0n                         0
# Chi0v                         0
# Chi1                          0
# Chi1n                         0
# Chi1v                         0
# Chi2n                         0
# Chi2v                         0
# Chi3n                         0
# Chi3v                         0
# Chi4n                         0
# Chi4v                         0
# HallKierAlpha                 0
# Ipc                           0
# Kappa1                        0
# Kappa2                        0
# Kappa3                        0
# LabuteASA                     0
# PEOE_VSA1                     0
# PEOE_VSA10                    0
# PEOE_VSA11                    0
# PEOE_VSA12                    0
# PEOE_VSA13                    0
# PEOE_VSA14                    0
# PEOE_VSA2                     0
# PEOE_VSA3                     0
# PEOE_VSA4                     0
# PEOE_VSA5                     0
# PEOE_VSA6                     0
# PEOE_VSA7                     0
# PEOE_VSA8                     0
# PEOE_VSA9                     0
# SMR_VSA1                      0
# SMR_VSA10                     0
# SMR_VSA2                      0
# SMR_VSA3                      0
# SMR_VSA4                      0
# SMR_VSA5                      0
# SMR_VSA6                      0
# SMR_VSA7                      0
# SMR_VSA8                      0
# SMR_VSA9                      0
# SlogP_VSA1                    0
# SlogP_VSA10                   0
# SlogP_VSA11                   0
# SlogP_VSA12                   0
# SlogP_VSA2                    0
# SlogP_VSA3                    0
# SlogP_VSA4                    0
# SlogP_VSA5                    0
# SlogP_VSA6                    0
# SlogP_VSA7                    0
# SlogP_VSA8                    0
# SlogP_VSA9                    0
# TPSA                          0
# EState_VSA1                   0
# EState_VSA10                  0
# EState_VSA11                  0
# EState_VSA2                   0
# EState_VSA3                   0
# EState_VSA4                   0
# EState_VSA5                   0
# EState_VSA6                   0
# EState_VSA7                   0
# EState_VSA8                   0
# EState_VSA9                   0
# VSA_EState1                   0
# VSA_EState10                  0
# VSA_EState2                   0
# VSA_EState3                   0
# VSA_EState4                   0
# VSA_EState5                   0
# VSA_EState6                   0
# VSA_EState7                   0
# VSA_EState8                   0
# VSA_EState9                   0
# FractionCSP3                  0
# HeavyAtomCount                0
# NHOHCount                     0
# NOCount                       0
# NumAliphaticCarbocycles       0
# NumAliphaticHeterocycles      0
# NumAliphaticRings             0
# NumAromaticCarbocycles        0
# NumAromaticHeterocycles       0
# NumAromaticRings              0
# NumHAcceptors                 0
# NumHDonors                    0
# NumHeteroatoms                0
# NumRotatableBonds             0
# NumSaturatedCarbocycles       0
# NumSaturatedHeterocycles      0
# NumSaturatedRings             0
# RingCount                     0
# MolLogP                       0
# MolMR                         0
# fr_Al_COO                     0
# fr_Al_OH                      0
# fr_Al_OH_noTert               0
# fr_ArN                        0
# fr_Ar_COO                     0
# fr_Ar_N                       0
# fr_Ar_NH                      0
# fr_Ar_OH                      0
# fr_COO                        0
# fr_COO2                       0
# fr_C_O                        0
# fr_C_O_noCOO                  0
# fr_C_S                        0
# fr_HOCCN                      0
# fr_Imine                      0
# fr_NH0                        0
# fr_NH1                        0
# fr_NH2                        0
# fr_N_O                        0
# fr_Ndealkylation1             0
# fr_Ndealkylation2             0
# fr_Nhpyrrole                  0
# fr_SH                         0
# fr_aldehyde                   0
# fr_alkyl_carbamate            0
# fr_alkyl_halide               0
# fr_allylic_oxid               0
# fr_amide                      0
# fr_amidine                    0
# fr_aniline                    0
# fr_aryl_methyl                0
# fr_azide                      0
# fr_azo                        0
# fr_barbitur                   0
# fr_benzene                    0
# fr_benzodiazepine             0
# fr_bicyclic                   0
# fr_diazo                      0
# fr_dihydropyridine            0
# fr_epoxide                    0
# fr_ester                      0
# fr_ether                      0
# fr_furan                      0
# fr_guanido                    0
# fr_halogen                    0
# fr_hdrzine                    0
# fr_hdrzone                    0
# fr_imidazole                  0
# fr_imide                      0
# fr_isocyan                    0
# fr_isothiocyan                0
# fr_ketone                     0
# fr_ketone_Topliss             0
# fr_lactam                     0
# fr_lactone                    0
# fr_methoxy                    0
# fr_morpholine                 0
# fr_nitrile                    0
# fr_nitro                      0
# fr_nitro_arom                 0
# fr_nitro_arom_nonortho        0
# fr_nitroso                    0
# fr_oxazole                    0
# fr_oxime                      0
# fr_para_hydroxylation         0
# fr_phenol                     0
# fr_phenol_noOrthoHbond        0
# fr_phos_acid                  0
# fr_phos_ester                 0
# fr_piperdine                  0
# fr_piperzine                  0
# fr_priamide                   0
# fr_prisulfonamd               0
# fr_pyridine                   0
# fr_quatN                      0
# fr_sulfide                    0
# fr_sulfonamd                  0
# fr_sulfone                    0
# fr_term_acetylene             0
# fr_tetrazole                  0
# fr_thiazole                   0
# fr_thiocyan                   0
# fr_thiophene                  0
# fr_unbrch_alkane              0
# fr_urea                       0
# Assay_id                      0
# dtype: int64

# %%
# Printing AUC values greater than 0.7
auc_scores[auc_scores["AUC_VALUES"] > 0.7]
# Out:
#     Unnamed: 0              Columns  AUC_VALUES
# 0          208                label    1.000000
# 1          209             Assay_id    0.854489
# 2           19         BCUT2D_CHGHI    0.791780
# 3           21        BCUT2D_LOGPHI    0.791692
# 4           23          BCUT2D_MRHI    0.791675
# 5           20         BCUT2D_CHGLO    0.791218
# 6           34                Chi2v    0.790972
# 7           24         BCUT2D_MRLOW    0.790303
# 8           22       BCUT2D_LOGPLOW    0.790149
# 9           36                Chi3v    0.789833
# 10          33                Chi2n    0.789608
# 11          18         BCUT2D_MWLOW    0.789447
# 12           2    MaxAbsEStateIndex    0.788718
# 13           0       MaxEStateIndex    0.788708
# 14          35                Chi3n    0.788659
# 15          32                Chi1v    0.788502
# 16          38                Chi4v    0.788444
# 17           4                  qed    0.788050
# 18          37                Chi4n    0.787473
# 19          31                Chi1n    0.787172
# 20         122                MolMR    0.786741
# 21         121              MolLogP    0.785186
# 22          26              BertzCT    0.783991
# 23           1       MinEStateIndex    0.783442
# 24          29                Chi0v    0.782631
# 25          44            LabuteASA    0.781923
# 26          43               Kappa3    0.781313
# 27          28                Chi0n    0.781024
# 28          13  MinAbsPartialCharge    0.779565
# 29          10     MaxPartialCharge    0.778505
# 30           3    MinAbsEStateIndex    0.778120
# 31          42               Kappa2    0.777597
# 32           7           ExactMolWt    0.773276
# 33           5                MolWt    0.773193
# 34          11     MinPartialCharge    0.769224
# 35          12  MaxAbsPartialCharge    0.768791
# 36          25             BalabanJ    0.766374
# 37          41               Kappa1    0.764056
# 38          40                  Ipc    0.761109
# 39          30                 Chi1    0.749970
# 40          17          BCUT2D_MWHI    0.747940
# 41           6       HeavyAtomMolWt    0.746555
# 42          97          VSA_EState4    0.736653
# 43         101          VSA_EState8    0.736186
# 44          95          VSA_EState2    0.732954
# 45          98          VSA_EState5    0.732523
# 46          96          VSA_EState3    0.730663
# 47          99          VSA_EState6    0.729858
# 48          73           SlogP_VSA2    0.725134
# 49         100          VSA_EState7    0.722160
# 50          27                 Chi0    0.718644
# 51          93          VSA_EState1    0.705950

# %%
train_data = drop_columns_and_rows_with_no_null_values(train_data)

# %%
model1 = RandomForestClassifier(n_estimators=200,random_state=50)
model2 = GradientBoostingClassifier()

# %% [markdown]
# # Select features and use model for training

# %%
X = train_data[["Assay_id","MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt"]]
y = train_data["label"]

# %%
model1.fit(X,y)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=50)

# %%
predict = model1.predict(test_data[["Assay_id","MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt","C]])

# %%
get_count_of_ones_and_twos(predict)
# Out:
# Number of predicted ones 1312
# Number of predicted twos 9682

# %% [markdown]
# Submission 18 using 100 estimators Assay_id","MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt (0.73255)
#
# Submission 19 using kappa3 (0.72833)
#
#
# Submission 20 using Kappa1 but increasing estimators to 150 and adding "Chi3v","qed" (0.70201)
#
# Submission 21 increasing estimators to 200 and adding "Assay_id","MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt (0.73411)
#
# Submission 22 increasing estimators to 250 and adding "Assay_id","MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt (0.73411)

# %%
create_submission(predict,"submission_3_feb_5.csv")
# Out:
# submission_3_feb_4.csv  Created

# %%
X
# Out:
#        Assay_id  MaxAbsEStateIndex    MolWt     Kappa1  HeavyAtomMolWt
# 0          1644           9.316200  317.599  14.321871         306.511
# 1          2451          10.532611  156.269  10.670000         136.109
# 2          1384           2.433032  362.086  26.478759         313.702
# 3            16          10.355080  255.665  11.591174         245.585
# 4          1856           0.000000  149.894   9.288422         149.894
# ...         ...                ...      ...        ...             ...
# 75378        33          11.460021  230.245  11.315529         220.165
# 75379      1632           5.928972  313.747  15.856180         296.611
# 75380      1373           4.975926  167.258   6.066958         162.218
# 75381         2          10.241948  128.215   8.670000         112.087
# 75382         2          12.552405  636.962  39.159833         572.450
#
# [75383 rows x 5 columns]

# %% [markdown]
# ## Feature scaling using standard scalar

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([
        ('somename', StandardScaler(), ["MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt"])
    ], remainder='passthrough')
scaler = StandardScaler()

# %%
X = train_data[["Assay_id","MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt"]]
y = train_data["label"]

# %%
scaled_X_data = ct.fit_transform(X)

# %%
pd.DataFrame(scaled_test_data)
# Out:
#               0         1         2         3       4
# 0     -0.202886 -0.891132 -0.773340 -0.930403  1682.0
# 1      0.764461  1.077345  0.920223  1.118381  1656.0
# 2      1.496441  3.028199  2.563758  2.978078    36.0
# 3      0.066909 -0.618584 -0.428041 -0.552565  1850.0
# 4      0.897854  0.982473  1.163326  0.856346    30.0
# ...         ...       ...       ...       ...     ...
# 10989  0.893030  0.907345  1.008143  0.925260    38.0
# 10990  0.473451  0.258819  0.130786  0.270994    34.0
# 10991  0.741731  0.708394  0.607431  0.748440  1640.0
# 10992  0.272781 -0.473220 -0.473379 -0.423972    28.0
# 10993  0.241161 -0.987329 -1.250416 -0.945565  1855.0
#
# [10994 rows x 5 columns]

# %%
scaled_test_data = ct.fit_transform(test_data[["Assay_id","MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt"]])

# %%
model1.fit(scaled_trained_data,y)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=50)

# %%
predict = model1.predict(scaled_test_data)

# %%
get_count_of_ones_and_twos(predict)
# Out:
# Number of predicted ones 943
# Number of predicted twos 10051

# %%
create_submission(predict,"submission_3_feb_5.csv")
# Scaling data has reduced accuracy to 0.66949 submission 22
# Out:
# submission_3_feb_5.csv  Created

# %% [markdown]
# # Working with Random forest parameter tuning
#
# - Submission 23
#     - Number of estimators increases to 300 submission 22 accuracy 73.411%
# - Submission 24
# - Submission 25
# - Submission 26
# - Submission 27

# %%
X = train_data[["Assay_id","MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt"]]
y = train_data["label"]

# %%
model = RandomForestClassifier(n_estimators=300,random_state=50)

# %%
model.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=300, random_state=50)

# %%
predict = model.predict(test_data[["Assay_id","MaxAbsEStateIndex","MolWt","Kappa1","HeavyAtomMolWt"]])

# %%
get_count_of_ones_and_twos(predict)
# Out:
# Number of predicted ones 1312
# Number of predicted twos 9682

# %%
create_submission(predict,"submission_3_feb_6.csv")
# Number of estimators increases to 300 submission 22 accuracy 73.411%
# Out:
# submission_3_feb_6.csv  Created

# %% [markdown]
# # Try other features and take a break
